# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\34616\Documents\4GEEKS\datos_gordos\roBERTa results\Topic_analysis\topic_analysis_final.csv")
df
# Out:
#                                                     text        topic  \
# 0           Why do some people think abortion is murder?     abortion
# 1      This will depend a lot on how you understand w...     abortion
# 2      they consider the fetus as a life (a child) an...     abortion
# 3      I mean is it a no brainer in Sweden? It's curr...     abortion
# 4      It’s not a no brainer in Sweden. There are lim...     abortion
# ...                                                  ...          ...
# 15765  > Trump tanked the border bill.\n\nNope.  He d...  immigration
# 15766  > Isn’t legalizing aliens what we want?\n\nNo....  immigration
# 15767  Undocumented immigrants also can't work in the...  immigration
# 15768  > Funny, Trumps political opponents don’t seem...     abortion
# 15769  I can’t imagine being so disconnected to reali...        lgbtq
#
#       sentiment  max_score  negative_score  neutral_score  positive_score  \
# ...
